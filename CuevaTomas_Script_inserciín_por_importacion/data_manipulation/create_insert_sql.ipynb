# %%
import pandas as pd

# %%
# Lee el archivo CSV con Pandas
df = pd.read_csv('./DB/restaurants.csv', sep = ';')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         10 non-null     int64
#  1   name       10 non-null     object
#  2   direction  10 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 372.0+ bytes

# %%
df_dishes_per_sale = pd.read_csv('./DB/dishes_per_sale.csv', sep = ';')
df_dishes_per_sale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16999 entries, 0 to 16998
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  16999 non-null  int64
#  1   id          16999 non-null  int64
#  2   dish_id     16999 non-null  int64
#  3   sale_id     16999 non-null  int64
#  4   quantity    16999 non-null  int64
# dtypes: int64(5)
# memory usage: 664.2 KB

# %%
df_dishes_per_sale = df_dishes_per_sale.drop('Unnamed: 0', axis = 1)

# %%
df_dishes_per_sale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16999 entries, 0 to 16998
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        16999 non-null  int64
#  1   dish_id   16999 non-null  int64
#  2   sale_id   16999 non-null  int64
#  3   quantity  16999 non-null  int64
# dtypes: int64(4)
# memory usage: 531.3 KB

# %%
df_sales = pd.read_csv('./DB/sales.csv', sep = ';')
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        10000 non-null  int64
#  1   id                10000 non-null  int64
#  2   id_restaurant     10000 non-null  int64
#  3   date_time         10000 non-null  object
#  4   type_consumption  10000 non-null  object
#  5   total_price       10000 non-null  float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 468.9+ KB

# %%
df_sales = df_sales.drop('Unnamed: 0', axis = 1)

# %%
columnas_deseadas = ['id', 'date_time', 'type_consumption', 'total_price', 'id_restaurant']
df_sales = df_sales.reindex(columns = columnas_deseadas)
df_sales
# Out:
#          id                   date_time type_consumption  total_price  \
# 0         1  2023-06-13 15:01:56.204509         delivery         8.99
# 1         2  2023-06-13 15:00:56.204509       restaurant         8.99
# 2         3  2023-06-13 14:59:56.204509       restaurant        32.97
# 3         4  2023-06-13 14:58:56.204509         delivery         6.99
# 4         5  2023-06-13 14:57:56.204509         delivery        10.99
# ...     ...                         ...              ...          ...
# 9995   9996  2023-06-06 16:26:56.204509         delivery        27.98
# 9996   9997  2023-06-06 16:25:56.204509         delivery        44.97
# 9997   9998  2023-06-06 16:24:56.204509         delivery        20.97
# 9998   9999  2023-06-06 16:23:56.204509         delivery        27.98
# 9999  10000  2023-06-06 16:22:56.204509       restaurant        11.98
#
#       id_restaurant
# 0                 7
# 1                 2
# 2                 5
# 3                 5
# ...

# %%
df_administratives = pd.read_csv('./DB/administratives.csv', sep = ';')
df_administratives.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DNI                       20 non-null     int64
#  1   last_name                 20 non-null     object
#  2   name_administrative       20 non-null     object
#  3   email                     20 non-null     object
#  4   password_administratives  20 non-null     object
#  5   id                        20 non-null     int64
#  6   id_restaurant             20 non-null     int64
# dtypes: int64(3), object(4)
# memory usage: 1.2+ KB

# %%
df_dishes = pd.read_csv('./DB/dishes.csv', sep = ';')
df_dishes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Restaurante  71 non-null     int64
#  1   Plato        71 non-null     object
#  2   Descripción  71 non-null     object
#  3   Categoría    71 non-null     object
#  4   Precio       71 non-null     float64
#  5   id           71 non-null     int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 3.5+ KB

# %%
columnas_deseadas = ['id', 'Plato', 'Descripción', 'Categoría', 'Precio', 'Restaurante']
df_dishes = df_dishes.reindex(columns = columnas_deseadas)
df_dishes
# Out:
#     id                         Plato  \
# 0    1                Classic Burger
# 1    2          Cheeseburger Supreme
# 2    3        Spicy Chicken Sandwich
# 3    4             Vegetarian Deluxe
# 4    5                 Eggs Benedict
# ..  ..                           ...
# 66  67                      Tiramisu
# 67  68             BBQ Chicken Wings
# 68  69  Grilled Chicken Caesar Salad
# 69  70            Chicken Quesadilla
# 70  71                  Key Lime Pie
#
#                                           Descripción        Categoría  \
# 0   Deliciosa hamburguesa clásica con carne jugosa...      Hamburguesa
# 1   Hamburguesa con doble carne, queso fundido, to...      Hamburguesa
# 2   Sándwich de pollo picante con lechuga, tomate ...         Sándwich
# 3   Burger vegetariana con una sabrosa mezcla de v...      Hamburguesa
# 4   Huevos pochados sobre muffin inglés con loncha...         Desayuno
# ..                                                ...              ...
# ...

# %%
columnas_deseadas = ['id', 'DNI', 'name_administrative', 'last_name', 'email', 'password_administratives', 'id_restaurant']
df_administratives = df_administratives.reindex(columns = columnas_deseadas)
df_administratives
# Out:
#     id       DNI name_administrative  last_name                       email  \
# 0    1  12345678             Rodrigo      López         rodrigo@example.com
# 1    2  23456789           Valentina  Fernández       valentina@example.com
# 2    3  34567890            Federico   Martínez        federico@example.com
# 3    4  45678901              Camila    Herrera          camila@example.com
# 4    5  56789012               Lucas      Gómez           lucas@example.com
# 5    6  67890123               Sofía  Rodríguez           sofia@example.com
# 6    7  78901234              Martín     Castro          martin@example.com
# 7    8  89012345            Carolina    Morales        carolina@example.com
# 8    9  90123456             Nicolás    Sánchez         nicolas@example.com
# 9   10   1234567            Victoria   González        victoria@example.com
# 10  11  12345678           Juan Cruz     Medina            juan@example.com
# ...

# %%
# Nombre de la tabla en la base de datos
table = 'dishes_per_sale'

# Genera el script SQL
script_sql = ''
for _, row in df_dishes_per_sale.iterrows():
    # Obtiene los valores de cada columna
    valores = ', '.join([f"'{str(value)}'" for value in row])
    
    # Genera el comando INSERT para cada fila
    script_sql += f"INSERT INTO {table} VALUES ({valores});\n"

# Guarda el script SQL en un archivo
with open('./script_entregable/script_insert_dishes_per_sale.sql', 'w', encoding = 'utf-8') as file:
    file.write(script_sql)

print('Script SQL generado con éxito.')
# Out:
# Script SQL generado con éxito.
